# %%
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\Chandubhai Chotaliya\OneDrive\Desktop\AI\Power bi\Mobile Sales Data.xlsx"
df = pd.read_excel(file_path)

# %%
df.head(5)
# Out:
#    Transaction ID  Day  Month  Year  Day Name    Brand  Units Sold  \
# 0               1    9     10  2021       Sat   Xiaomi           6
# 1               2    9     10  2021  Saturday     Vivo           6
# 2               3    9     10  2021  Saturday     Vivo           8
# 3               4   10     10  2021    Sunday   Xiaomi           5
# 4               5   10     10  2021    Sunday  OnePlus           3
#
#    Price Per Unit     Customer Name  Customer Age       City Payment Method  \
# 0        10174.70      Lalita Ahuja            38   Ludhiana            UPI
# 1        10565.19      Sneha Sharma            37      Delhi    Credit Card
# 2        58527.58  Radha Srivastava            40     Mumbai            UPI
# 3        25563.98     Bhavana Arora            21     Mumbai    Credit Card
# 4        48168.02       Sneha Mehta            38  Gorakhpur           Cash
#
#    Customer Ratings   Mobile Model
# 0                 5  Redmi Note 10
# ...

# %%
df.shape
# Out:
# (3835, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3835 entries, 0 to 3834
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    3835 non-null   int64
#  1   Day               3835 non-null   int64
#  2   Month             3835 non-null   int64
#  3   Year              3835 non-null   int64
#  4   Day Name          3835 non-null   object
#  5   Brand             3835 non-null   object
#  6   Units Sold        3835 non-null   int64
#  7   Price Per Unit    3835 non-null   float64
#  8   Customer Name     3835 non-null   object
#  9   Customer Age      3835 non-null   int64
#  10  City              3835 non-null   object
#  11  Payment Method    3835 non-null   object
#  12  Customer Ratings  3835 non-null   int64
#  13  Mobile Model      3835 non-null   object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 419.6+ KB

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Day', 'Month', 'Year', 'Day Name', 'Brand',
#        'Units Sold', 'Price Per Unit', 'Customer Name', 'Customer Age', 'City',
#        'Payment Method', 'Customer Ratings', 'Mobile Model'],
#       dtype='object')

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#        Transaction ID          Day        Month         Year   Units Sold  \
# count     3835.000000  3835.000000  3835.000000  3835.000000  3835.000000
# mean      1918.000000    15.703781     6.527249  2022.765319     4.993481
# std       1107.213469     8.822771     3.452030     0.917401     2.581122
# min          1.000000     1.000000     1.000000  2021.000000     1.000000
# 25%        959.500000     8.000000     4.000000  2022.000000     3.000000
# 50%       1918.000000    16.000000     7.000000  2023.000000     5.000000
# 75%       2876.500000    23.000000    10.000000  2024.000000     7.000000
# max       3835.000000    31.000000    12.000000  2024.000000     9.000000
#
#        Price Per Unit  Customer Age  Customer Ratings
# count     3835.000000   3835.000000       3835.000000
# mean     40114.036816     38.098305          3.693090
# std      17310.488427     12.110622          1.325069
# min      10011.110000     18.000000          1.000000
# ...

# %%
df.describe(include='object')
# Out:
#         Day Name  Brand   Customer Name   City Payment Method Mobile Model
# count       3835   3835            3835   3835           3835         3835
# unique        14      5             988     19              4           15
# top     Saturday  Apple  Prashant Gupta  Delhi            UPI     Vivo Y51
# freq         562    783              12   1008           1011          283

# %% [markdown]
# Missing Values Analysis

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Day                 0
# Month               0
# Year                0
# Day Name            0
# Brand               0
# Units Sold          0
# Price Per Unit      0
# Customer Name       0
# Customer Age        0
# City                0
# Payment Method      0
# Customer Ratings    0
# Mobile Model        0
# dtype: int64

# %% [markdown]
# Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Univariate Analysis

# %%
sns.histplot(df['Units Sold'], bins=30, kde=True)
plt.title("Distribution of Units Sold")
plt.show()

# %%
sns.boxplot(x=df['Customer Ratings'])
plt.title("Customer Ratings Distribution")
plt.show()

# %% [markdown]
# EDA Conclusion
#
#
#
# Delhi & Mumbai are top revenue contributors
#
# Apple & Samsung dominate sales
#
# Digital payments (UPI & Cards) preferred
#
# Good-rated products generate maximum revenue
#
# Strong positive trend in monthly & MTD sales
